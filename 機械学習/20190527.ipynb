# %% [markdown]
# • 以下のデータセットを使って分類・回帰をしてください
#   • Iris Dataset
#   • Digits Dataset
#   • Boston Dataset
#   • Diabetes Dataset
#   • Breast cancer Wisconsin dataset

# %% [markdown]
# Iris Dataset = アヤメの計測データ(分類)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

iris = load_iris()

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size = 0.2, train_size = 0.8, shuffle = True)

clf = SVC(gamma='auto')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# Digits Dataset = 数字の手書き文字(分類)

# %%
from sklearn.datasets import load_digits 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

digits = load_digits(n_class=10) 
x_train, x_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size = 0.2, train_size = 0.8, shuffle = True)

clf = SVC(gamma='auto')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5527777777777778

# %% [markdown]
# Boston Dataset = ボストン市の住宅価格(回帰)

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error

boston = load_boston() 
X_train,X_test,y_train,y_test = train_test_split(boston.data,boston.target,test_size=0.2)


clf = linear_model.LinearRegression()
clf.fit(X_train,y_train)

result = clf.predict(X_train)
print('MAE =',mean_absolute_error(y_train,result)*1000)
# Out:
# ('MAE =', 3179.479674860779)

# %% [markdown]
# Diabetes Dataset = 糖尿病患者の診断データ(回帰)

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error

diabetes = load_diabetes()
X_train,X_test,y_train,y_test=train_test_split(diabetes.data,diabetes.target,test_size=0.2)

clf = linear_model.LinearRegression()
clf.fit(X_train,y_train)

result = clf.predict(X_train)
print('MAE =',mean_absolute_error(y_train,result))
# Out:
# ('MAE =', 42.53078764836176)

# %% [markdown]
#  Breast cancer Wisconsin dataset = 大学の乳がん画像データ(分類)

# %%
from sklearn.datasets import load_breast_cancer 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

cancer = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size = 0.2, train_size = 0.8, shuffle = True)

clf = SVC(gamma='auto')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5789473684210527

# %% [markdown]
# Breast cancer Wisconsin dataset = 大学の乳がん画像データ(分類)のランダムフォレストによる分類

# %%
from sklearn.datasets import load_breast_cancer 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

cancer = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size = 0.2)

forest = RandomForestClassifier()
scores = cross_val_score(forest, X_train, y_train, scoring='accuracy' ,cv=10).mean()

print("The mean accuracy with 10 fold cross validation is %s" % round(scores*100,2))
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-31-fa8d5ab35f60> in <module>()
#       9
#      10 forest = RandomForestClassifier()
# ---> 11 scores = cross_val_score(forest, X_train, y_train, scoring='accuracy' ,cv=10).mean()
#      12
#      13 print("The mean accuracy with 10 fold cross validation is %s" % round(scores*100,2))
#
# /usr/local/lib/python2.7/dist-packages/sklearn/model_selection/_validation.pyc in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     400                                 fit_params=fit_params,
#     401                                 pre_dispatch=pre_dispatch,
# --> 402                                 error_score=error_score)
#     403     return cv_results['test_score']
#     404
#
# ...
