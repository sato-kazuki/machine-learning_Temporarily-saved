# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

import pandas as pd
import seaborn as sns

from sklearn import datasets

iris = sns.load_dataset('iris')
n_samples = 100

data = iris[:n_samples+1]
columns = ['petal_width', 'petal_length']
x = data[columns]
y = data['species']

y = (y == 'setosa').astype(int)

def plot_iris(x, y, colors, ax=None):
    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(1, 1, 1)
    
    plt.figure()
    x1 = x.columns[0]
    x2 = x.columns[1]

    for (species, group), c in zip(x.groupby(y), colors):
        group.plot(kind='scatter', x=x1, y=x2, color=c, ax=ax)
  
    return ax
    
plot_iris(x, y, colors=['red', 'blue'])
plt.show()

# %%
def sigmoid(x):
    return 1. / (1. + np.exp(-x))

def calc_y(x, w, b):
    return sigmoid(np.dot(x, w) + b)

def calc_grad(x, y, w, b):
    # ∂E(w) / ∂w = (y - t)φ(x)
    error = y - calc_y(x, w, b)
    w_grad = -np.mean(x.T * error, axis=1)
    b_grad = -np.mean(error)
    #print('w_grad', w_grad)

    return w_grad, b_grad

# %%
nb_epochs = 20

# %%
def GradientDescent(x, y, w, b, eta=0.5):
  for i in range(1,nb_epochs):
  #勾配gを取得
    w_grad,b_grad=calc_grad(x,y,w,b)
    w=w-eta*w_grad
    b=b-eta*b_grad
  #教師データと求めた値の差の絶対値の平均
    e=np.mean(np.abs(y-calc_y(x,w,b)))
    yield i,w,b,e

# %%
def SGD(x, y, w, b, eta=0.4):
    for i in range(1, nb_epochs):
        indexer = np.arange(x.shape[0])
        np.random.shuffle(indexer)
        for index in indexer:
            _x = x.iloc[[index], ]
            _y = y.iloc[[index], ]
            w_grad, b_grad = calc_grad(_x, _y, w, b)
            w -= eta * w_grad
            b -= eta * b_grad
            e = np.mean(np.abs(y - calc_y(x, w, b)))
            yield i, w, b, e

# %%
def MiniBatchSGD(x, y, w, b, eta=0.4, batch_size=16):
    for i in range(1, nb_epochs):
        indexer = np.arange(x.shape[0])
        np.random.shuffle(indexer)
        for index in indexer:

            # ミニバッチを取り出す
            batch_x = x[index:index+batch_size]
            batch_y = y[index:index+batch_size]
            w_grad, b_grad = calc_grad(batch_x, batch_y, w, b)
            w -= eta * w_grad
            b -= eta * b_grad
            e = np.mean(np.abs(y - calc_y(x, w, b)))
            yield i, w, b, e

# %%
from matplotlib import animation, rc
from IPython.display import HTML
# %matplotlib inline


def plot_result(x, y, solver, title, animation_max_length=100):
    fig = plt.figure()

    ax = fig.add_subplot(1, 1, 1)
    plt.xlim([0.0, 3.0])
    plt.ylim([-1.0, 8.0])

    art_objs = []
    loss_x = []
    loss_y = []
    
    bx = np.arange(x.iloc[:, 0].min(), x.iloc[:, 0].max(), 0.1)

    w = np.zeros(2)
    b = 0
    gen = solver(x, y, w, b)

    for i, w, b, e in gen:
        if len(art_objs) < animation_max_length:
            by = -b / w[1] - w[0] / w[1] * bx
            l = ax.plot(bx, by, color='gray', linestyle='dashed')
            art_objs.append(l)
            
        loss_x.append(i)
        loss_y.append(e)

    ax = plot_iris(x, y, colors=['red', 'blue'], ax=ax)
    ax.set_title(title)

    anim = animation.ArtistAnimation(fig, art_objs, interval=100, repeat=True, blit=True, repeat_delay=1000)
    
    #plt.plot(loss_x, loss_y)
    
    return anim

rc('animation', html='jshtml')

# %%
plot_result(x, y, GradientDescent, title='GD')
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgdc09fd9750644cbdba01cde0d5ae91d8">
#     <br>
#     <input id="_anim_sliderdc09fd9750644cbdba01cde0d5ae91d8" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animdc09fd9750644cbdba01cde0d5ae91d8.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animdc09fd9750644cbdba01cde0d5ae91d8.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectdc09fd9750644cbdba01cde0d5ae91d8" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdc09fd9750644cbdba01cde0d5ae91d8";
#     var slider_id = "_anim_sliderdc09fd9750644cbdba01cde0d5ae91d8";
#     var loop_select_id = "_anim_loop_selectdc09fd9750644cbdba01cde0d5ae91d8";
#     var frames = new Array(19);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3XtUVPeBB/Dv8IZxgCioiAohRHmp\
# CIP4ikm6Ihof8UFtqE18kNLU6GY3m0fd3ebR0+1J021rVo09c+LRvMRtbXK0MZqq0TVRLILaHgJq\
# YkQExYyoBGYGGIa7f9zOlHFmYAYvzPxmvp9zOMP85nLv7zI6X36/+7u/n0qSJAlERESCCfJ2BYiI\
# iPqDAUZEREJigBERkZAYYEREJCQGGBERCYkBRkREQmKAERGRkBhgREQkJAYYEREJiQFGRERCYoAR\
# EZGQGGBERCQkBhgREQmJAUZEREJigBERkZAYYEREJCQGGBERCYkBRkREQmKAERGRkBhgRANk165d\
# yM/Ph1qtxvDhw5Gfn48333wTkiRh1apVCAsLg0ajgUajQVZWFjZs2ICWlhZvV5tIGAwwogHw61//\
# Gs888wyef/55NDU14fr16/jd736H48ePo7OzEwDwwgsvoLW1FXq9Htu3b8fJkycxY8YMGAwGL9ee\
# SAwMMCKFtbS04KWXXsKbb76JoqIiaDQaqFQqTJ48Ge+//z7Cw8Ptto+IiEBeXh727t2L5uZmbN++\
# 3Us1JxILA4xIYeXl5ejo6MCjjz7q0c9pNBoUFBTgs88+G6CaEfkXBhiRwm7cuIG4uDiEhITYyqZP\
# n47Y2FhERkbi2LFjLn921KhRuHnz5mBUk0h4IX1vQkSeGDZsGG7cuIGuri5biJ04cQIAMHr0aHR3\
# d7v82cbGRgwdOnRQ6kkkOrbAiBQ2bdo0hIeHY8+ePR79XFtbGw4dOoQHHnhggGpG5F8YYEQKi42N\
# xcsvv4y1a9di9+7daG1tRXd3N86ePet0hGFHRweqqqqwePFi3HPPPVi9erUXak0kHpUkSZK3K0Hk\
# j95//3288cYbqK6uhlqtRkpKCkpKSrBq1SqUlpZi586dCA8PhyRJSEpKwoIFC7BhwwbExsZ6u+pE\
# QmCAERGRkNiFSEREQhImwH77298iMzMTWVlZKC4uRnt7u7erREREXiREgDU2NuJ//ud/UFlZierq\
# algsFuzatcvb1SIiIi8SIsAAoKurCyaTCV1dXTAajRg1apS3q0RERF4kRIAlJibiueeew9ixY5GQ\
# kICYmBjMmTPH29UiIiIvEmImjlu3bmHPnj24dOkSYmNj8d3vfhfvvfcefvCDH9htp9PpoNPpAADn\
# zp1DWlqaN6pLRCSsuro63Lhxw9vVcIsQAXbo0CHce++9iI+PBwAsXboUJ06ccAiw0tJSlJaWAgC0\
# Wi0qKysHva5ERCLTarXeroLbhOhCHDt2LE6ePAmj0QhJknD48GGkp6d7u1pERORFQgRYfn4+ioqK\
# kJOTgwkTJqC7u9vW0iIiosDktzNxsAuRiMhzIn12CtECIyIiuhMDjIiIhMQAIyIiITHAiIhISAww\
# IiISEgOMiIiExAAjIiIhMcCIiEhIDDAiIhISA4yIiITEACMiIiExwIiISEgMMCIiEhIDjIiIhMQA\
# IyIiIQkRYOfPn0d2drbtKzo6Ghs3bvR2tYiIyItCvF0Bd4wfPx5nz54FAFgsFiQmJmLJkiVerhUR\
# EXmTEC2wng4fPoz77rsPSUlJ3q4KERF5kXABtmvXLhQXF3u7GkRE5GVCBVhnZyf27t2L7373u05f\
# 1+l00Gq10Gq10Ov1g1w7IiIaTEIF2P79+5GTk4MRI0Y4fb20tBSVlZWorKxEfHz8INeOiIgGk1AB\
# VlZWxu5DIiICIFCAGQwGHDx4EEuXLvV2VYiIyAcIMYweANRqNZqbm71dDSIi8hHCtMCIiIh6YoAR\
# EZGQGGBERCQkBhgREQmJAUZEREJigBERkZAYYEREJCQGGBERCYkBRkREQmKAERGR

# %%
plot_result(x, y, SGD, title='SGD')
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img3d23a017051841a18c3e66ce6976c4fc">
#     <br>
#     <input id="_anim_slider3d23a017051841a18c3e66ce6976c4fc" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim3d23a017051841a18c3e66ce6976c4fc.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim3d23a017051841a18c3e66ce6976c4fc.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select3d23a017051841a18c3e66ce6976c4fc" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3d23a017051841a18c3e66ce6976c4fc";
#     var slider_id = "_anim_slider3d23a017051841a18c3e66ce6976c4fc";
#     var loop_select_id = "_anim_loop_select3d23a017051841a18c3e66ce6976c4fc";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3Xt8VNWBB/Df5D15ImSC4RFihJB3\
# QjJ5CBRQCREJlEe0plRBoilF2HZZd61b10c/3S7VWnGB2p1PqdhaYyvVReQhoLiKgGTCo40JqCkD\
# JAQcAoFAZpLJ5O4f10wzzEwyk9xkcjK/7+eTz5AzN+eem9H55Zx75hyVJEkSiIiIBOPn7QYQERH1\
# BQOMiIiExAAjIiIhMcCIiEhIDDAiIhISA4yIiITEACMiIiExwIiISEgMMCIiEhIDjIiIhMQAIyIi\
# ITHAiIhISAwwIiISEgOMiIiExAAjIiIhMcCIiEhIDDAiIhISA4yIiITEACMiIiExwIgUcODAAUyd\
# OhVRUVEYOXIkpk2bhsrKSgBAY2MjHn30UYwZMwbh4eFISEjA8uXLcfLkSQCAwWCASqVCeHg4wsPD\
# MXr0aBQXF2Pv3r3evCSiIY8BRtRP165dQ3FxMdasWYPLly+joaEBzzzzDIKDg9HU1ISpU6eitbUV\
# n3zyCVpaWnD06FHMnDnTIaCam5tx/fp1nDhxAoWFhVi0aBG2bNninYsiEoBKkiTJ240gEpler8fs\
# 2bPR3Nzs8NxTTz2F7du349ixY/Dzc/73osFgwG233QaLxYKAgABb+S9/+Uu88MILaGxsdPmzRL6M\
# /1cQ9VNiYiL8/f2xbNky7Nq1C1euXLE9t2/fPixatKhPAbR48WJ8/fXXOHXqlJLNJRo2GGBE/RQZ\
# GYkDBw5ApVLh0UcfhUajwYIFC3Dx4kVcunQJt956q+3Yd999FyNGjEBERATmzJnTY71jxowBAFy+\
# fHlA208kKgYYkQKSk5OxZcsW1NfXo7q6GufPn8ePfvQjjBo1Co2NjbbjFixYgObmZrz00ktob2/v\
# sc6GhgYAwMiRIwe07USiYoARKSwpKQnLly9HdXU17r77bvzv//4vOjs7Pa7nnXfeQUxMDCZPnjwA\
# rSQSHwOMqJ9OnjyJF198EfX19QCAc+fOoaKiAgUFBVi7di2uXLmCBx98EHV1dZAkCS0tLTh+/LjL\
# +i5evIiNGzfiueeew3/9139xAgeRC/w/g6ifIiIi8NlnnyE/Px9hYWEoKChAWloaXnzxRURHR+Pw\
# 4cMICQnB9OnTERERgaysLLS0tOCVV16xq2fEiBEICwtDeno6du7cibfeegsrVqzw0lURDX2cRk9E\
# REJiD4yIiIQkTIC99NJLSE1NRVpaGkpLS2E2m73dJCIi8iIhAqyhoQH//d//Db1ej+rqalitVrz5\
# 5pvebhYREXmREAEGAB0dHTCZTOjo6EBra6vtQ55EROSbhAiwsWPH4vHHH0dcXBxiY2MRFRXV6yoG\
# REQ0vAX0foj3XblyBdu2bcPp06cxYsQI3HfffXj99dfxve99z+44nU4HnU4HQP5sTlJSkjeaS0Qk\
# LIPBgEuXLnm7GW4RIsD27duH2267DRqNBoC8yOnBgwcdAqy8vBzl5eUAAK1WC71eP+htJSISmVar\
# 9XYT3CbEEGJcXBwOHz6M1tZWSJKEDz74AMnJyd5uFhEReZEQAZafn4+SkhJkZ2cjPT0dnZ2dtp4W\
# ERH5pmG7EgeHEImIPCfSe6cQPTAiIqKbMcCIiEhIDDAiIhISA4yIiITEACMiIiExwIiISEgMMCIi\
# EhIDjIiIhMQAIyIiITHAiIhISAwwIiISEgOMiIiExAAjIiIhMcCIiEhIDDAiIhKSEAF26tQpZGVl\
# 2b4iIyOxfv16bzeLiIi8KMDbDXDH5MmTcfz4cQCA1WrF2LFjsWjRIi+3ioiIvEmIHlh3H3zwAW6/\
# /XZMmDDB200hIiIvEi7A3nzzTZSWlnq7GURE5GVCBVh7ezveffdd3HfffU6f1+l

# %%
plot_result(x, y, MiniBatchSGD, title='Minibatch SGD')
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc33beaa743494008b7b04298cca733ae">
#     <br>
#     <input id="_anim_sliderc33beaa743494008b7b04298cca733ae" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc33beaa743494008b7b04298cca733ae.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animc33beaa743494008b7b04298cca733ae.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectc33beaa743494008b7b04298cca733ae" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc33beaa743494008b7b04298cca733ae";
#     var slider_id = "_anim_sliderc33beaa743494008b7b04298cca733ae";
#     var loop_select_id = "_anim_loop_selectc33beaa743494008b7b04298cca733ae";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3X1cVGWiB/Df8D7CgCKQgAoivvCm\
# iIP4Ulr3iuTrqqGFlm+4rPmy7eZu5d3dst17u+VuZde0Pty8vlTiLWqvpumulqYlhqBWJGqaqODL\
# jqgIMsPruX+cOMvIDM7ggeGZ+X0/Hz7jPOfwnOc4NT+f5zznORpJkiQQEREJxs3RDSAiImoLBhgR\
# EQmJAUZEREJigBERkZAYYEREJCQGGBERCYkBRkREQmKAERGRkBhgREQkJAYYEREJiQFGRERCYoAR\
# EZGQGGBERCQkBhgREQmJAUZEREJigBERkZAYYEREJCQGGBERCYkBRi5l0aJF+NOf/mT3vvv370fP\
# nj3bs2mKyMhI7N27t0OORSQyBhg5hcjISHh5eeHatWtm5UOGDIFGo0FJSQkA4O2338Yf/vAHm+q0\
# Z9/WlJSUQKPRoL6+/p7rulNtbS2WL1+Onj17ws/PD5GRkfjVr35lts/WrVuRkpICX19fhISEICUl\
# BevWrYMkSQCAefPmwcvLCzqdDjqdDvHx8VixYgUqKipUby+Rmhhg5DT69OmDnJwc5f13332H6upq\
# B7ao/f3nf/4nCgoKkJ+fj8rKSuzfvx9JSUnK9ldffRVPPfUUfvvb3+LKlSu4evUq3n77bXz11Veo\
# ra1V9nvmmWdQWVkJg8GADRs24PDhwxg1ahRu377tiNMisgkDjJzGE088gc2bNyvvN23ahDlz5pjt\
# M2/ePPz+978H8M9hwVdffRUhISEIDQ3Fhg0bLO7b5KWXXkJQUBAiIyPx/vvvK+U7d+7EkCFD4O/v\
# j169emHlypXKttGjRwMAunbtCj8/P+Tl5QEA/vu//xsxMTHQ6XSIjY3F0aNHld85fvw4Bg0ahICA\
# ADz66KMwmUwWz/nIkSOYNm0awsLCoNFoEBkZqZxzRUUFnn/+eaxbtw7p6enQ6XTQaDQYMmQI3n//\
# fXh7e7eoz8fHB8nJydi+fTvKy8vN/j6IOhsGGDmN4cOH49atWyguLkZDQwO2bt2Kxx9/vNXfuXLl\
# CioqKlBWVob169djyZIluHHjhtV9r127hrKyMmzatAlZWVk4deoUAMDX1xebN2/GzZs3sXPnTrz1\
# 1lv4v//7PwDAgQMHAAA3b95EVVUVRowYgQ8//BArV67E5s2bcevWLWzfvh3du3dXjvXBBx9g9+7d\
# OHfuHL799lts3LjR6jm/9tprWLduHb777jtlWBAA8vLyUFNTg5/97Gc2/x020el0SE1NxcGDB+3+\
# XaKOwgAjp9LUC9uzZw9iYmIQHh7e6v6enp54/vnn4enpiQkTJsDPz08JJUv+9Kc/wdvbG2PGjMHE\
# iRPxwQcfAAAefPBBJCQkwM3NDYMGDUJGRga++OILq/W88847eOaZZ5CcnAyNRoPo6GhEREQo23/5\
# y18iLCwMgYGBmDx5Mo4fP26xnhUrVuDZZ5/F+++/D71ej/DwcGzatAkAcO3aNQQFBcHDw0PZf+TI\
# kejatSu0Wq0SrNaEhYXh+vXrre5D5Eged9+FSBxPPPEERo8ejXPnzrUYPrSke/fuZl/wXbp0QVVV\
# lcV9u3XrBl9fX+V9REQELl26BAD4+uuv8dxzz6GoqAi1tbWoqanBjBkzrB734sWL6Nu3r9XtPXr0\
# MGtT03Hu5O7ujiVLlmDJkiUwGo34n//5HyxYsADDhg1D9+7dce3aNdTX1yvneOjQIQBAz5490djY\
# aPX4AFBWVobAwMBW9yFyJPbAyKlERESgT58++PTTTzF9+nRV675x44bZpIYLFy4gLCwMADBr1ixM\
# mTIFFy9eREVFBRYtWqQM52k0mhZ19erVC2fPnlW1fVqtFkuWLEG3bt1w4sQJjBg
